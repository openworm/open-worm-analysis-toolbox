# %%
# %matplotlib nbagg
from matplotlib.widgets import Button
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# %%
# Test of clicking on buttons
def callback(event):
    plt.text(event.xdata, event.ydata, 'clicked')

f,a = plt.subplots(1)
b1 = Button(a,'Button1')
b1.on_clicked(callback)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
def update_line(num, data, line):
    line.set_data(data[...,:num])
    return line,

fig1 = plt.figure()
    
data = np.random.rand(2, 25)
l, = plt.plot([], [], 'r-')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.xlabel('x')
plt.title('test')
line_ani = animation.FuncAnimation(fig1, update_line, 25, fargs=(data, l),
    interval=50, blit=True)
# Out:
# <img src="data:image/png;base64,...">

# %%
import sys, os
user_path = r'C:\Users\Michael\Desktop'
sys.path.insert(1, user_path)
from open-worm-analysis-toolbox import open-worm-analysis-toolbox as mv

# %%
# Load our example data
base_path = os.path.abspath(mv.user_config.EXAMPLE_DATA_PATH)
schafer_nw_file_path = os.path.join(base_path, 
                                    "example_video_norm_worm.mat")
nw = mv.NormalizedWorm.from_schafer_file_factory(schafer_nw_file_path)

# %%
np = mv.NormalizedWormPlottable(nw)

# %%
np.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
import sys
sys.version
# Out:
# '3.4.3 (v3.4.3:9b73f1c3e601, Feb 24 2015, 22:44:40) [MSC v.1600 64 bit (AMD64)]'
